# %% [markdown]
# <a href="https://colab.research.google.com/github/gcarterIT/East-Bay-Housing-Web-Scrape/blob/master/manning_data_science_gpt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 1.5 MB/s eta 0:00:00
# ...

# %%
import openai
openai.organization = "org-uypVdr4x9b8cfQ9mSfiEQVNu"
openai.api_key = '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'
models = openai.Model.list()
print(models)
# Out:
# {
#   "object": "list",
#   "data": [
#     {
#       "id": "text-davinci-edit-001",
#       "object": "model",
#       "created": 1649809179,
#       "owned_by": "openai",
#       "permission": [
#         {
#           "id": "modelperm-otmQSS0hmabtVGHI9QB3bct3",
#           "object": "model_permission",
#           "created": 1679934178,
#           "allow_create_engine": false,
#           "allow_sampling": true,
#           "allow_logprobs": true,
#           "allow_search_indices": false,
#           "allow_view": true,
#           "allow_fine_tuning": false,
#           "organization": "*",
#           "group": null,
#           "is_blocking": false
#         }
#       ],
#       "root": "text-davinci-edit-001",
#       "parent": null
#     },
#     {
#       "id": "babbage-code-search-code",
#       "object": "model",
#       "created": 1651172509,
#       "owned_by": "openai-dev",
#       "permission": [
#         {
#           "id": "modelperm-4qRnA3Hj8HIJbgo0cGbcmErn",
# ...

# %%
# https://stackoverflow.com/questions/75773786/cant-access-gpt-4-model-via-python-api-although-gpt-3-5-works

# Author: Viet Dac Lai
import pprint

#openai.organization = "org-uypVdr4x9b8cfQ9mSfiEQVNu"
#openai.api_key = "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"

GPT4 = 'gpt-4-0314'
MODEL_NAME = GPT4
model = openai.Model(MODEL_NAME)

def list_all_models():
    model_list = openai.Model.list()['data']
    model_ids = [x['id'] for x in model_list]
    model_ids.sort()
    pprint.pprint(model_ids)

if __name__ == '__main__':
    list_all_models()
# Out:
# ['ada',
#  'ada-code-search-code',
#  'ada-code-search-text',
#  'ada-search-document',
#  'ada-search-query',
#  'ada-similarity',
#  'babbage',
#  'babbage-code-search-code',
#  'babbage-code-search-text',
#  'babbage-search-document',
#  'babbage-search-query',
#  'babbage-similarity',
#  'code-davinci-edit-001',
#  'code-search-ada-code-001',
#  'code-search-ada-text-001',
#  'code-search-babbage-code-001',
#  'code-search-babbage-text-001',
#  'curie',
#  'curie-instruct-beta',
#  'curie-search-document',
#  'curie-search-query',
#  'curie-similarity',
#  'davinci',
#  'davinci-instruct-beta',
#  'davinci-search-document',
#  'davinci-search-query',
#  'davinci-similarity',
#  'gpt-3.5-turbo',
#  'gpt-3.5-turbo-0301',
#  'gpt-3.5-turbo-0613',
#  'gpt-3.5-turbo-16k',
#  'gpt-3.5-turbo-16k-0613',
#  'text-ada-001',
#  'text-babbage-001',
#  'text-curie-001',
#  'text-davinci-001',
#  'text-davinci-002',
#  'text-davinci-003',
#  'text-davinci-edit-001',
# ...

# %%
#import openai
#openai.api_key = '...'
result = openai.Completion.create(
  model='text-davinci-003',
  #model="gpt-4",
  prompt='Tell me a story!')
print(result)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-10-2f0830045ae9> in <cell line: 3>()
#       1 #import openai
#       2 #openai.api_key = '...'
# ----> 3 result = openai.Completion.create(
#       4   model='text-davinci-003',
#       5   #model="gpt-4",
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/abstract/engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     151         )
#     152
# ...
